# %%
import os
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import cv2
# from tensorflow.keras.applications import ResNet152,ResNet152V2,ResNet101V2,ResNet101,Xception,InceptionResNetV2,InceptionV3

img = cv2.imread('/content/drive/My Drive/Study/dacon/mnist2/2차 배포/dirty_mnist_2nd/00001.png')
img
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-cbc259d500a2> in <module>()
#       2 from tensorflow.keras.applications import ResNet152,ResNet152V2,ResNet101V2,ResNet101,Xception,InceptionResNetV2,InceptionV3
#       3
# ----> 4 img = cv2.imread('/content/drive/My Drive/Study/dacon/mnist2/2차 배포/dirty_mnist_2nd/00001.png')
#       5 img
#
# KeyboardInterrupt:

# %%
img = cv2.imread('/content/drive/My Drive/Study/dacon/mnist2/2차 배포/dirty_mnist_2nd/00001.png')
img
